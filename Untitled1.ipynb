# %%
import pandas as pd
import numpy as np

# LOAD THE DATA

df_raw = pd.read_csv('raw_data.csv', sep='|', skiprows=2, header=None, engine='python')

#  ORGANIZE COLUMNS

column_names = [
    'order_id', 'order_status', 'customer', 'order_date',
    'order_quantity', 'sales', 'discount', 'discount_value',
    'product_category', 'product_sub_category'
]
df = df_raw.iloc[:, 1:11]
df.columns = column_names

#  CLEAN TEXT & DATES

for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].str.strip()

#  format
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

#  CLEAN NUMERICAL DATA
numeric_cols = ['order_id', 'order_quantity', 'sales', 'discount', 'discount_value']
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Create Net Sales (Revenue after discounts)
df['net_sales'] = df['sales'] - df['discount_value']

# Remove any empty rows
df = df.dropna(subset=['order_id'])

#  EXPORT
df.to_csv('cleaned_sales_data.csv', index=False)

print("✅ Data cleaning complete!")
print(f"Total rows processed: {len(df)}")
df.head()
# Out:
# ✅ Data cleaning complete!
# Total rows processed: 5424
#    order_id    order_status            customer order_date  order_quantity  \
# 0       3.0  Order Finished  Muhammed MacIntyre 2010-10-13             6.0
# 1     293.0  Order Finished        Barry French 2012-10-01            49.0
# 2     483.0  Order Finished       Clay Rozendal 2011-07-10            30.0
# 3     515.0  Order Finished      Carlos Soltero 2010-08-28            19.0
# 4     613.0  Order Finished        Carl Jackson 2011-06-17            12.0
#
#         sales  discount  discount_value product_category  \
# 0    523080.0      0.04         20923.0  Office Supplies
# 1  20246040.0      0.07       1417223.0  Office Supplies
# 2   9931519.0      0.08        794522.0       Technology
# 3    788540.0      0.08         63083.0  Office Supplies
# 4    187080.0      0.03          5612.0  Office Supplies
#
#              product_sub_category   net_sales
# 0          Storage & Organization    502157.0
# 1                      Appliances  18828817.0
# 2    Telephones and Communication   9136997.0
# 3                      Appliances    725457.0
# 4  Binders and Binder Accessories    181468.0
